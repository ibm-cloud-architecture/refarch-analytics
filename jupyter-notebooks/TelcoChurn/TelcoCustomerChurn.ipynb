# %% [markdown]
# # Predict customer churn.
# Data are in ../data folder

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Load customer and churn data

# %%
customers=pd.read_csv('../data_assets/customer.csv',index_col='ID')
customers.head()
# Out:
#    Gender Status  Children  Est Income Car Owner        Age  LongDistance  \
# ID
# 1       F      S       1.0    38000.00         N  24.393333         23.56
# 6       M      M       2.0    29616.00         N  49.426667         29.78
# 8       M      M       0.0    19732.80         N  50.673333         24.81
# 11      M      S       2.0       96.33         N  56.473333         26.13
# 14      F      M       2.0    52004.80         N  25.140000          5.03
#
#     International   Local  Dropped Paymethod LocalBilltype  \
# ID
# 1             0.0  206.08      0.0        CC        Budget
# 6             0.0   45.50      0.0        CH     FreeLocal
# 8             0.0   22.44      0.0        CC     FreeLocal
# 11            0.0   32.88      1.0        CC        Budget
# 14            0.0   23.11      0.0        CH        Budget
#
#    LongDistanceBilltype   Usage  RatePlan
# ID
# 1        Intnl_discount  229.64       3.0
# 6              Standard   75.29       2.0
# 8              Standard   47.25       3.0
# 11             Standard   59.01       1.0
# 14       Intnl_discount   28.14       1.0

# %%
churns=pd.read_csv('../data_assets/churn.csv')
churns.head()
# Out:
#    ID CHURN
# 0   1     T
# 1   6     F
# 2   8     F
# 3  11     F
# 4  14     F

# %% [markdown]
# ### Join the the two data frame

# %%
custchurns=customers.join(churns.set_index('ID'))

# %%
custchurns.head()
# Out:
#    Gender Status  Children  Est Income Car Owner        Age  LongDistance  \
# ID
# 1       F      S       1.0    38000.00         N  24.393333         23.56
# 6       M      M       2.0    29616.00         N  49.426667         29.78
# 8       M      M       0.0    19732.80         N  50.673333         24.81
# 11      M      S       2.0       96.33         N  56.473333         26.13
# 14      F      M       2.0    52004.80         N  25.140000          5.03
#
#     International   Local  Dropped Paymethod LocalBilltype  \
# ID
# 1             0.0  206.08      0.0        CC        Budget
# 6             0.0   45.50      0.0        CH     FreeLocal
# 8             0.0   22.44      0.0        CC     FreeLocal
# 11            0.0   32.88      1.0        CC        Budget
# 14            0.0   23.11      0.0        CH        Budget
#
#    LongDistanceBilltype   Usage  RatePlan CHURN
# ID
# 1        Intnl_discount  229.64       3.0     T
# 6              Standard   75.29       2.0     F
# 8              Standard   47.25       3.0     F
# 11             Standard   59.01       1.0     F
# 14       Intnl_discount   28.14       1.0     F
